# %% [markdown]
# Importar paquetes

# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
dir_work = os.getcwd()+'\\..'
os.chdir(dir_work)

# %% [markdown]
# Carga de datos

# %%
data = np.loadtxt('data/sn05kl_spectrum.txt')
longonda = []
flux = []
for ind in range(len(data)):
    longonda.append(data[ind, 0])
    flux.append(data[ind, 1])

# %% [markdown]
# Cálculo del desplazamiento de las líneas con el redshift

# %%
z = 0.00349
lambda_ref = ['He I 10830', 'P_8', 'P_7', 'P_gamma', 'P_betta', 'O I 11287', 'Mg I 11828', 'Fe II 9095', 'S I 10460', 'Fe II 12823',\
               'Fe II 12863', 'Fe II 12944', 'Fe II 14472', 'Fe II 14976', 'S I 11343', 'Na I 11381', 'Fe II 13105', 'O I 13076', 'Mg II 14727',\
                  'Mg II 14395', 'He II 11626', 'O I 13165', 'Sr II 10330', 'Si I 12030', 'Fe II 12570', 'Fe II 13210', 'Mg II 15040'] 
# 'OI 13165', 'Fe II 13163', 'Fe II 12963', 'P_10(9015)', 'P_9(9229)','Mg II 14258', 
lambda_lab = [10830, 9546, 10049, 10938, 12818, 11287, 11828, 9095, 10460, 12823, 12863, 12944, 14472, 14976, 11343, 11381, 13105, 13076, 14727, 14395, 11626,\
              13165, 10330, 12030, 12570, 13210, 15040]
desplaz_lambda = [z*x for x in lambda_lab]
lambda_obs = [x + y for x, y in zip(lambda_lab, desplaz_lambda)]
# CI [Rho2021]
lambda_lab_CI = [9180, 9850] #9094, 9405, 9658, 10124, 10691, 10730 [Sauer2006]
lambda_ref_CI = ['CI', 'CI'] #, 'CI', 'CI', 'CI', 'CI'
for ind in range(len(lambda_lab_CI)):
    lambda_ref_CI[ind] = lambda_ref_CI[ind] + ' ' + str(lambda_lab_CI[ind])
desplaz_lambda_CI = [z*x for x in lambda_lab_CI]
lambda_obs_CI = [x + y for x, y in zip(lambda_lab_CI, desplaz_lambda_CI)]

for ind in range(len(lambda_ref)):
    print(f'\n{lambda_ref[ind]}({lambda_lab[ind]}): Desplaz.= {desplaz_lambda[ind]}; lambda_obs= {lambda_obs[ind]}')
# Out:
# He I 10830(10830): Desplaz.= 37.7967; lambda_obs= 10867.7967
#
# P_8(9546): Desplaz.= 33.31554; lambda_obs= 9579.31554
#
# P_7(10049): Desplaz.= 35.07101; lambda_obs= 10084.07101
#
# P_gamma(10938): Desplaz.= 38.17362; lambda_obs= 10976.17362
#
# P_betta(12818): Desplaz.= 44.73482; lambda_obs= 12862.73482
#
# O I 11287(11287): Desplaz.= 39.39163; lambda_obs= 11326.39163
#
# Mg I 11828(11828): Desplaz.= 41.27972; lambda_obs= 11869.27972
#
# Fe II 9095(9095): Desplaz.= 31.74155; lambda_obs= 9126.74155
#
# S I 10460(10460): Desplaz.= 36.5054; lambda_obs= 10496.5054
#
# Fe II 12823(12823): Desplaz.= 44.75227; lambda_obs= 12867.75227
#
# Fe II 12863(12863): Desplaz.= 44.89187; lambda_obs= 12907.89187
#
# Fe II 12944(12944): Desplaz.= 45.17456; lambda_obs= 12989.17456
#
# Fe II 14472(14472): Desplaz.= 50.50728; lambda_obs= 14522.50728
#
# Fe II 14976(14976): Desplaz.= 52.26624; lambda_obs= 15028.26624
#
# S I 11343(11343): Desplaz.= 39.58707; lambda_obs= 11382.58707
#
# ...

# %% [markdown]
# # Representación gráfica

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(longonda, np.log10(flux), linewidth=1, c='k', label='sn05kl')
ymin, ymax = ax.get_ylim()
xmin, xmax = ax.get_xlim()
# ax.vlines(10830, ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
# ax.text(10835, 1.5e-15, 'HeI10830', fontsize=7)
for ind in range(len(lambda_ref)):
    if lambda_ref[ind] == 'P_8':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.77, lambda_ref[ind], fontsize=7, color='b')
    elif lambda_ref[ind] == 'P_7':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.77, lambda_ref[ind], fontsize=7, color='b')
    elif lambda_ref[ind] == 'P_gamma':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.77, lambda_ref[ind], fontsize=7, color='b')
    elif lambda_ref[ind] == 'P_betta':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.77, lambda_ref[ind], fontsize=7, color='b')
    elif lambda_ref[ind] == 'He I 10830':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='k', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.1, lambda_ref[ind], fontsize=7)
    elif lambda_ref[ind] == 'O I 11287':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.75, lambda_ref[ind], fontsize=7, color='salmon')
    elif lambda_ref[ind] == 'Fe II 12863':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.125, lambda_ref[ind], fontsize=7, color='brown')
    # elif lambda_ref[ind] == 'Fe II 12740':
    #     ax.vlines(lambda_obs[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs[ind], 1.75e-15, lambda_ref[ind], fontsize=7)
    # elif lambda_ref[ind] == 'Fe II 12963':
    #     ax.vlines(lambda_obs[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs[ind], 2e-15, lambda_ref[ind], fontsize=7)
    elif lambda_ref[ind] == 'Fe II 9095':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.1, lambda_ref[ind], fontsize=7, color='brown')
    elif lambda_ref[ind] == 'Fe II 12823':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.1, lambda_ref[ind], fontsize=7, color='brown')
    elif lambda_ref[ind] == 'Fe II 12944':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.15, lambda_ref[ind], fontsize=7, color='brown')
    elif lambda_ref[ind] == 'Fe II 14472':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.1, lambda_ref[ind], fontsize=7, color='brown')
    elif lambda_ref[ind] == 'Fe II 14976':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.1, lambda_ref[ind], fontsize=7, color='brown')
    elif lambda_ref[ind] == 'S I 11343':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.73, lambda_ref[ind], fontsize=7, color='salmon')
    elif lambda_ref[ind] == 'S I 10460':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.77, lambda_ref[ind], fontsize=7, color='salmon')
    elif lambda_ref[ind] == 'Na I 11381':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='green', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.125, lambda_ref[ind], fontsize=7, color='green')
    # 'Fe II 13105', 'O I 13076'
    elif lambda_ref[ind] == 'O I 13076':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.75, lambda_ref[ind], fontsize=7, color='salmon')
    elif lambda_ref[ind] == 'Fe II 13105':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.175, lambda_ref[ind], fontsize=7, color='brown')
    elif lambda_ref[ind] == 'Fe II 12570':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(12250, -14.1, lambda_ref[ind], fontsize=7, color='brown')
    elif lambda_ref[ind] == 'Fe II 13210':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.2, lambda_ref[ind], fontsize=7, color='brown')
    elif lambda_ref[ind] == 'He II 11626':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='k', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.1, lambda_ref[ind], fontsize=7, color='k')
    elif lambda_ref[ind] == 'O I 13165':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.77, lambda_ref[ind], fontsize=7, color='salmon')
    # 'Mg II 14727', 'Mg II 14258', 'Mg II 14395'
    # elif lambda_ref[ind] == 'Mg II 14395':
    #     ax.vlines(lambda_obs[ind], ymin, ymax, color='green', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs[ind], -14.75, lambda_ref[ind], fontsize=7, color='green')
    elif lambda_ref[ind] == 'Mg II 14727':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='green', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.75, lambda_ref[ind], fontsize=7, color='green')
    elif lambda_ref[ind] == 'Sr II 10330':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='green', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.1, lambda_ref[ind], fontsize=7, color='green')
    elif lambda_ref[ind] == 'Si I 12030':
        ax.vlines(lambda_obs[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.75, lambda_ref[ind], fontsize=7, color='salmon')
    else:
        ax.vlines(lambda_obs[ind], ymin, ymax, color='green', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs[ind], -14.77, lambda_ref[ind], fontsize=7, color='green')

# ax.vlines(15025, ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
# ax.vlines(14523, ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
# ax.vlines(13150, ymin, ymax, color='gray', linestyle=':', linewidth=0.8)


# for ind in range(len(lambda_ref_CI)):
#     if lambda_ref_CI[ind] == 'CI 9658':
#         print('\nCI 9658 no printeado\n')
#     elif lambda_ref_CI[ind] == 'CI 9850':
#         # ax.vlines(lambda_obs_CI[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
#         print('\nCI 9850\n')
#         # ax.text(lambda_obs_CI[ind], 7e-15, lambda_ref_CI[ind], fontsize=7)
#     elif lambda_ref_CI[ind] == 'CI 9180':
#         # ax.vlines(lambda_obs_CI[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
#         # ax.text(lambda_obs_CI[ind], 7.75e-15, lambda_ref_CI[ind], fontsize=7)
#         print('\nCI 9180\n')
#     else:
#         ax.vlines(lambda_obs_CI[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_CI[ind], -14.8, lambda_ref_CI[ind], fontsize=7)

ax.set_xlabel('$\lambda$  [$\AA$]')
ax.set_ylabel('log F[erg s$^{-1}$ cm$^{-2}$ $\AA$]')
# fig.savefig('Resultados/AnalisisEspectroPeaks.pdf')

# %% [markdown]
# Zoom ~9000-10700A

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(longonda, np.log10(flux), linewidth=1, c='k', label='sn05kl')
ax.set_xlim(longonda[0], 10700)
ymin, ymax = ax.get_ylim()
xmin, xmax = ax.get_xlim()
# ax.vlines(10830, ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
# ax.text(10835, 1.5e-15, 'HeI10830', fontsize=7)
lambda_ref_z1 = []
lambda_lab_z1 = []
lambda_obs_z1 = []
for ind in range(len(lambda_ref)):
    if lambda_obs[ind] < 10700.:
        lambda_obs_z1.append(lambda_obs[ind])
        lambda_ref_z1.append(lambda_ref[ind])
        lambda_lab_z1.append(lambda_lab[ind])
for ind in range(len(lambda_ref_z1)):
    # if lambda_ref_z1[ind] == 'HeI 10830':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 2e-15, lambda_ref_z1[ind], fontsize=7)
    # if lambda_ref_z1[ind] == 'P_8':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 1.5e-15, lambda_ref_z1[ind], fontsize=7, color='b')
    # elif lambda_ref_z1[ind] == 'OI11287':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 1.75e-15, lambda_ref_z1[ind], fontsize=7)
    # elif lambda_ref_z1[ind] == 'Fe II 13163':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 7e-15, lambda_ref_z1[ind], fontsize=7)
    # elif lambda_ref_z1[ind] == 'Fe II 12740':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 1.75e-15, lambda_ref_z1[ind], fontsize=7)
    # elif lambda_ref_z1[ind] == 'Fe II 12963':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 2e-15, lambda_ref_z1[ind], fontsize=7)
    # elif lambda_ref_z1[ind] == 'Fe II 9095':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 1.5e-15, lambda_ref_z1[ind], fontsize=7)
    # else:
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 1.5e-15, lambda_ref_z1[ind], fontsize=7)
    if lambda_ref_z1[ind] == 'P_8':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
    elif lambda_ref_z1[ind] == 'P_7':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
    elif lambda_ref_z1[ind] == 'P_gamma':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
    elif lambda_ref_z1[ind] == 'P_betta':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
    elif lambda_ref_z1[ind] == 'He I 10830':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='k', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.1, lambda_ref_z1[ind], fontsize=7)
    elif lambda_ref_z1[ind] == 'O I 11287':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.75, lambda_ref_z1[ind], fontsize=7, color='salmon')
    elif lambda_ref_z1[ind] == 'Fe II 12863':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.125, lambda_ref_z1[ind], fontsize=7, color='brown')
    # elif lambda_ref[ind] == 'Fe II 12740':
    #     ax.vlines(lambda_obs[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs[ind], 1.75e-15, lambda_ref[ind], fontsize=7)
    # elif lambda_ref[ind] == 'Fe II 12963':
    #     ax.vlines(lambda_obs[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs[ind], 2e-15, lambda_ref[ind], fontsize=7)
    elif lambda_ref_z1[ind] == 'Fe II 9095':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='brown')
    elif lambda_ref_z1[ind] == 'Fe II 12823':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.1, lambda_ref_z1[ind], fontsize=7, color='brown')
    elif lambda_ref_z1[ind] == 'Fe II 12944':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.15, lambda_ref_z1[ind], fontsize=7, color='brown')
    elif lambda_ref_z1[ind] == 'S I 10460':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='salmon')
    else:
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='green', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='green')

# lambda_ref_CI_z1 = []
# lambda_lab_CI_z1 = []
# lambda_obs_CI_z1 = []
# for ind in range(len(lambda_ref_CI)):
#     if lambda_obs_CI[ind] < 10700.:
#         lambda_ref_CI_z1.append(lambda_ref_CI[ind])
#         lambda_lab_CI_z1.append(lambda_lab_CI[ind])
#         lambda_obs_CI_z1.append(lambda_obs_CI[ind])
# for ind in range(len(lambda_ref_CI_z1)):
#     if lambda_ref_CI_z1[ind] == 'CI 9658':
#         print('\nCI 9658 no printeado\n')
#     elif lambda_ref_CI_z1[ind] == 'CI 10691':
#         ax.vlines(lambda_obs_CI_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_CI_z1[ind], 7e-15, lambda_ref_CI_z1[ind], fontsize=7)
#     elif lambda_ref_CI_z1[ind] == 'CI 9405':
#         ax.vlines(lambda_obs_CI_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_CI_z1[ind], 7.75e-15, lambda_ref_CI_z1[ind], fontsize=7)
#     else:
#         ax.vlines(lambda_obs_CI_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_CI_z1[ind], 7.5e-15, lambda_ref_CI_z1[ind], fontsize=7)

ax.set_xlabel('$\lambda$  [$\AA$]')
ax.set_ylabel('log F[erg s$^{-1}$ cm$^{-2}$ $\AA$]')
# fig.savefig('Resultados//AnalisisEspectroPeaks_z1.pdf')
# ABSORCIÓN SI 10460

# %% [markdown]
# Zoom ~10700-12400

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(longonda, np.log10(flux), linewidth=1, c='k', label='sn05kl')
ax.set_xlim(10700, 12400)
ymin, ymax = ax.get_ylim()
xmin, xmax = ax.get_xlim()
# ax.vlines(10830, ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
# ax.text(10835, 1.5e-15, 'HeI10830', fontsize=7)
lambda_ref_z1 = []
lambda_lab_z1 = []
lambda_obs_z1 = []
for ind in range(len(lambda_ref)):
    if (lambda_obs[ind] > 10700.) and (lambda_obs[ind] < 12400.):
        lambda_obs_z1.append(lambda_obs[ind])
        lambda_ref_z1.append(lambda_ref[ind])
        lambda_lab_z1.append(lambda_lab[ind])
for ind in range(len(lambda_ref_z1)):
    if lambda_ref_z1[ind] == 'P_8':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
    elif lambda_ref_z1[ind] == 'P_7':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
    elif lambda_ref_z1[ind] == 'P_gamma':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
    elif lambda_ref_z1[ind] == 'P_betta':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
    elif lambda_ref_z1[ind] == 'He I 10830':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='k', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.1, lambda_ref_z1[ind], fontsize=7)
    elif lambda_ref_z1[ind] == 'O I 11287':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='salmon')
    elif lambda_ref_z1[ind] == 'Fe II 12863':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.125, lambda_ref_z1[ind], fontsize=7, color='brown')
    # elif lambda_ref[ind] == 'Fe II 12740':
    #     ax.vlines(lambda_obs[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs[ind], 1.75e-15, lambda_ref[ind], fontsize=7)
    # elif lambda_ref[ind] == 'Fe II 12963':
    #     ax.vlines(lambda_obs[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs[ind], 2e-15, lambda_ref[ind], fontsize=7)
    elif lambda_ref_z1[ind] == 'Fe II 9095':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='brown')
    elif lambda_ref_z1[ind] == 'Fe II 12823':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.1, lambda_ref_z1[ind], fontsize=7, color='brown')
    elif lambda_ref_z1[ind] == 'Fe II 12944':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.15, lambda_ref_z1[ind], fontsize=7, color='brown')
    elif lambda_ref_z1[ind] == 'S I 11343':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.73, lambda_ref_z1[ind], fontsize=7, color='salmon')
    elif lambda_ref_z1[ind] == 'S I 12030':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.73, lambda_ref_z1[ind], fontsize=7, color='salmon')
    elif lambda_ref_z1[ind] == 'He II 11626':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='k', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.1, lambda_ref_z1[ind], fontsize=7, color='k')
    else:
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='green', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='green')

# ax.vlines(11310, ymin, ymax, color='gray', linestyle=':', linewidth=0.8)


# lambda_ref_CI_z1 = []
# lambda_lab_CI_z1 = []
# lambda_obs_CI_z1 = []
# for ind in range(len(lambda_ref_CI)):
#     if (lambda_obs_CI[ind] > 10700.) and (lambda_obs_CI[ind] < 12400.):
#         lambda_ref_CI_z1.append(lambda_ref_CI[ind])
#         lambda_lab_CI_z1.append(lambda_lab_CI[ind])
#         lambda_obs_CI_z1.append(lambda_obs_CI[ind])
# for ind in range(len(lambda_ref_CI_z1)):
#     if lambda_ref_CI_z1[ind] == 'CI 9658':
#         print('\nCI 9658 no printeado\n')
#     elif lambda_ref_CI_z1[ind] == 'CI 10691':
#         ax.vlines(lambda_obs_CI_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_CI_z1[ind], 7e-15, lambda_ref_CI_z1[ind], fontsize=7)
#     elif lambda_ref_CI_z1[ind] == 'CI 9405':
#         ax.vlines(lambda_obs_CI_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_CI_z1[ind], 7.75e-15, lambda_ref_CI_z1[ind], fontsize=7)
#     else:
#         ax.vlines(lambda_obs_CI_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_CI_z1[ind], 7.5e-15, lambda_ref_CI_z1[ind], fontsize=7)

ax.set_xlabel('$\lambda$  [$\AA$]')
ax.set_ylabel('log F[erg s$^{-1}$ cm$^{-2}$ $\AA$]')
# fig.savefig('Resultados//AnalisisEspectroPeaks_z2.pdf')

# %% [markdown]
# Zoom 12400-13500

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(longonda, np.log10(flux), linewidth=1, c='k', label='sn05kl')
ax.set_xlim(12400, 13500)
ymin, ymax = ax.get_ylim()
xmin, xmax = ax.get_xlim()
# ax.vlines(10830, ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
# ax.text(10835, 1.5e-15, 'HeI10830', fontsize=7)
lambda_ref_z1 = []
lambda_lab_z1 = []
lambda_obs_z1 = []
for ind in range(len(lambda_ref)):
    if (lambda_obs[ind] > 12400.) and (lambda_obs[ind] < 13500.):
        lambda_obs_z1.append(lambda_obs[ind])
        lambda_ref_z1.append(lambda_ref[ind])
        lambda_lab_z1.append(lambda_lab[ind])
for ind in range(len(lambda_ref_z1)):
    # if lambda_ref_z1[ind] == 'HeI10830':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 2e-15, lambda_ref_z1[ind], fontsize=7)
    # elif lambda_ref_z1[ind] == 'OI11287':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 1.75e-15, lambda_ref_z1[ind], fontsize=7)
    # elif lambda_ref_z1[ind] == 'P_betta':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 7e-15, lambda_ref_z1[ind], fontsize=7)
    # elif lambda_ref_z1[ind] == 'Fe II 12740':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 1.75e-15, lambda_ref_z1[ind], fontsize=7)
    # elif lambda_ref_z1[ind] == 'Fe II 12963':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 1.75e-15, lambda_ref_z1[ind], fontsize=7)
    # elif lambda_ref_z1[ind] == 'Fe II 12863':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 2e-15, lambda_ref_z1[ind], fontsize=7)
    # else:
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], 1.5e-15, lambda_ref_z1[ind], fontsize=7)
    if lambda_ref_z1[ind] == 'P_8':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
    elif lambda_ref_z1[ind] == 'P_7':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
    elif lambda_ref_z1[ind] == 'P_gamma':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
    elif lambda_ref_z1[ind] == 'P_betta':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
    elif lambda_ref_z1[ind] == 'He I 10830':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='k', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.1, lambda_ref_z1[ind], fontsize=7)
    elif lambda_ref_z1[ind] == 'O I 11287':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='salmon')
    elif lambda_ref_z1[ind] == 'Fe II 12863':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.125, lambda_ref_z1[ind], fontsize=7, color='brown')
    # elif lambda_ref[ind] == 'Fe II 12740':
    #     ax.vlines(lambda_obs[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs[ind], 1.75e-15, lambda_ref[ind], fontsize=7)
    # elif lambda_ref[ind] == 'Fe II 12963':
    #     ax.vlines(lambda_obs[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs[ind], 2e-15, lambda_ref[ind], fontsize=7)
    elif lambda_ref_z1[ind] == 'Fe II 9095':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='brown')
    elif lambda_ref_z1[ind] == 'Fe II 12823':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.1, lambda_ref_z1[ind], fontsize=7, color='brown')
    elif lambda_ref_z1[ind] == 'Fe II 12944':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.15, lambda_ref_z1[ind], fontsize=7, color='brown')
    elif lambda_ref_z1[ind] == 'O I 13076':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='salmon')
    elif lambda_ref_z1[ind] == 'O I 13165':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='salmon')
    elif lambda_ref_z1[ind] == 'Fe II 13105':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.1, lambda_ref_z1[ind], fontsize=7, color='brown')
    elif lambda_ref_z1[ind] == 'Fe II 12570':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.1, lambda_ref_z1[ind], fontsize=7, color='brown')
    elif lambda_ref_z1[ind] == 'Fe II 13210':
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.1, lambda_ref_z1[ind], fontsize=7, color='brown')
    else:
        ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='green', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='green')

# lambda_ref_CI_z1 = []
# lambda_lab_CI_z1 = []
# lambda_obs_CI_z1 = []
# for ind in range(len(lambda_ref_CI)):
#     if (lambda_obs_CI[ind] > 12400.) and (lambda_obs_CI[ind] < 13500.):
#         lambda_ref_CI_z1.append(lambda_ref_CI[ind])
#         lambda_lab_CI_z1.append(lambda_lab_CI[ind])
#         lambda_obs_CI_z1.append(lambda_obs_CI[ind])
# for ind in range(len(lambda_ref_CI_z1)):
#     if lambda_ref_CI_z1[ind] == 'CI 9658':
#         print('\nCI 9658 no printeado\n')
#     elif lambda_ref_CI_z1[ind] == 'CI 10691':
#         ax.vlines(lambda_obs_CI_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_CI_z1[ind], 7e-15, lambda_ref_CI_z1[ind], fontsize=7)
#     elif lambda_ref_CI_z1[ind] == 'CI 9405':
#         ax.vlines(lambda_obs_CI_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_CI_z1[ind], 7.75e-15, lambda_ref_CI_z1[ind], fontsize=7)
#     else:
#         ax.vlines(lambda_obs_CI_z1[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_CI_z1[ind], 7.5e-15, lambda_ref_CI_z1[ind], fontsize=7)

# ax.vlines(13150, ymin, ymax, color='gray', linestyle=':', linewidth=0.8)

ax.set_xlabel('$\lambda$  [$\AA$]')
ax.set_ylabel('log F[erg s$^{-1}$ cm$^{-2}$ $\AA$]')
# fig.savefig('Resultados//AnalisisEspectroPeaks_z3.pdf')

# %% [markdown]
# Zoom 13500-~15000

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(longonda, np.log10(flux), linewidth=1, c='k', label='sn05kl')
# ax.set_xlim(14400, 14600)
ax.set_xlim(14000, longonda[-1])
ymin, ymax = ax.get_ylim()
ax.set_ylim(ax.get_ylim()[0], -14.5)
ymin, ymax = ax.get_ylim()
xmin, xmax = ax.get_xlim()

lambda_ref_z4 = ['Fe II', 'Fe II', 'Mg II', 'Mg II', 'Mg I']
lambda_lab_z4 = [14472, 14976, 14727, 14395, 15040]
for ind in range(len(lambda_ref_z4)):
    lambda_ref_z4[ind] = lambda_ref_z4[ind] + ' ' + str(lambda_lab_z4[ind])
desplaz_lambda_z4 = [z*x for x in lambda_lab_z4]
lambda_obs_z4 = [x + y for x, y in zip(lambda_lab_z4, desplaz_lambda_z4)]

for ind in range(len(lambda_ref_z4)):
    if lambda_ref_z4[ind] == 'Fe II 14472':
        ax.vlines(lambda_obs_z4[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z4[ind], -14.52, lambda_ref_z4[ind], fontsize=7, color='brown')
    # elif lambda_ref_z4[ind] == 'Fe II 14472':
    #     ax.vlines(lambda_obs_z4[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z4[ind], -14.75, lambda_ref_z4[ind], fontsize=7, color='b')
    elif lambda_ref_z4[ind] == 'Fe II 14976':
        ax.vlines(lambda_obs_z4[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z4[ind], -14.52, lambda_ref_z4[ind], fontsize=7, color='brown')
    else:
        ax.vlines(lambda_obs_z4[ind], ymin, ymax, color='green', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_z4[ind], -14.75, lambda_ref_z4[ind], fontsize=7, color='green')
# for ind in range(len(lambda_ref)):
#     if (lambda_obs[ind] > 14000 and lambda_ref[ind] != 'Fe II 14472') or (lambda_obs[ind] > 14000 and lambda_ref[ind] != 'Fe II 14976'):
        # ax.vlines(lambda_obs[ind], ymin, ymax, color='green', linestyle=':', linewidth=0.8)
        # ax.text(lambda_obs[ind], -14.52, lambda_ref[ind], fontsize=7, color='green')

# ax.vlines(15025, ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
# ax.vlines(14523, ymin, ymax, color='gray', linestyle=':', linewidth=0.8)

# ejemplo z1
# for ind in range(len(lambda_ref_z1)):
#     if lambda_ref_z1[ind] == 'P_8':
#         ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
#     elif lambda_ref_z1[ind] == 'P_7':
#         ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
#     elif lambda_ref_z1[ind] == 'P_gamma':
#         ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
#     elif lambda_ref_z1[ind] == 'P_betta':
#         ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='b', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='b')
#     elif lambda_ref_z1[ind] == 'He I 10830':
#         ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='k', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_z1[ind], -14.1, lambda_ref_z1[ind], fontsize=7)
#     elif lambda_ref_z1[ind] == 'O I 11287':
#         ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='salmon', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='salmon')
#     elif lambda_ref_z1[ind] == 'Fe II 12863':
#         ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
#         ax.text(lambda_obs_z1[ind], -14.125, lambda_ref_z1[ind], fontsize=7, color='brown')
    # elif lambda_ref_z1[ind] == 'Fe II 9095':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='brown')
    # elif lambda_ref_z1[ind] == 'Fe II 12823':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], -14.1, lambda_ref_z1[ind], fontsize=7, color='brown')
    # elif lambda_ref_z1[ind] == 'Fe II 12944':
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='brown', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], -14.15, lambda_ref_z1[ind], fontsize=7, color='brown')
    # else:
    #     ax.vlines(lambda_obs_z1[ind], ymin, ymax, color='green', linestyle=':', linewidth=0.8)
    #     ax.text(lambda_obs_z1[ind], -14.77, lambda_ref_z1[ind], fontsize=7, color='green')

ax.set_xlabel('$\lambda$  [$\AA$]')
ax.set_ylabel('log F[erg s$^{-1}$ cm$^{-2}$ $\AA$]')
# fig.savefig('Resultados//AnalisisEspectroPeaks_z4.pdf')

# %% [markdown]
# # Otras líneas

# %% [markdown]
# CI

# %%
desplaz_lambda_CI = [z*x for x in lambda_lab_CI]
lambda_obs_CI = [x + y for x, y in zip(lambda_lab_CI, desplaz_lambda_CI)]

for ind in range(len(lambda_ref_CI)):
    print(f'\n{lambda_ref_CI[ind]}: Desplaz.= {desplaz_lambda_CI[ind]}; lambda_obs= {lambda_obs_CI[ind]}')

fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(longonda, flux, linewidth=1, c='k', label='sn05kl')
ymin, ymax = ax.get_ylim()
xmin, xmax = ax.get_xlim()
# ax.vlines(10830, ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
# ax.text(10835, 1.5e-15, 'HeI10830', fontsize=7)
for ind in range(len(lambda_ref_CI)):
    if lambda_ref_CI[ind] == 'HeI10830':
        ax.vlines(lambda_obs_CI[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_CI[ind], 2e-15, lambda_ref_CI[ind], fontsize=7)
    else:
        ax.vlines(lambda_obs_CI[ind], ymin, ymax, color='gray', linestyle=':', linewidth=0.8)
        ax.text(lambda_obs_CI[ind], 1.5e-15, lambda_ref_CI[ind], fontsize=7)

# fig.savefig('Resultados/AnalisisEspectroPeaks_CI.pdf')
# Out:
# CI 9180: Desplaz.= 32.0382; lambda_obs= 9212.0382
#
# CI 9850: Desplaz.= 34.3765; lambda_obs= 9884.3765
